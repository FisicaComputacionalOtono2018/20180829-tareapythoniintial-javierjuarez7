# %%
import matplotlib.pyplot as plt
import numpy as np

t1=np.arange(-10.0, 15.0, 0.1)
t2=np.arange(-10.0, 15.0, 0.1)
plt.figure(1)
plt.plot(t1,2*t1**2+5*t1-2,'k',t2,4*t2+1,'bo')
plt.savefig('funciontarea.jpg')
plt.show()
